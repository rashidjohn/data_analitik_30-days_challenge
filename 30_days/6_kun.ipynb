# %% [markdown]
# # **SQL asoslari**
# PostgreSQL

# %% [markdown]
# **\l** orqali mavjud databazalarni ko'rish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **create database** orqali database yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **\c** orqali database ga ulanish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **create table** orqali table yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **insert into** orqali table ga ma'lumot qo'shish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **select** orqali table dagi ma'lumotlarni ko'rish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# jadvalga bir vaqtda bir nechta qator ma'lumot qo'shish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **select** orqali bir nechta ustunlarni tanlab ma'lumotlarni ko'rish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **alter table** orqali table ga o'zgartirish kiritiladi bu yerda **add** orqali yangu ustun qo'shilyapdi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **update** orqali qatorga o'zgartirish kiritish mumkin(agar **where** orqali shart berilmasa ustundagi barcha qatorga o'zgartirish kiritiladi)
#
# sintaksis: update table set ustun = 'qiymat' where ustun = 'qiymat';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# bir vaqtda bir nechta ustunga o'zgartirish kiritish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **alter table** orqali table ga o'zgartirish kiritish
#
# bu yerda **alter column** orqali ustun tipi(type) ni o'zgartirish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **\d table** orqali table ustunlari haqida ma'lumot olish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **drop colum** orqali ustun o'chiriladi
#
# sintaksis: alter table table drop column ustun;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **delete** orqali qatorni o'chirish(**where** sharti yozilmasa table dagi barcha qator o'chiriladi)
#
# sintaksis: delete from table where ustun = 'qiymat';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **truncate** orqali ustunni tozalash(barcha qatorlarni o'chirish)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **drop table** orqali table ni o'chirish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # demo database

# %% [markdown]
# **categories** jadvalini yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **categories** jadvalida 8 qator ma'lumot qo'shish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **customers** jadvalini yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **customer** jadvaliga ma'lumot qo'shish(91 qator ma'lumot qo'shildi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **products** jadvalini yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **products** jadvaliga ma'lumot qo'shish(77 qator ma'lumot qo'shildi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **orders** jadvalini yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **orders** jadvaliga ma'lumot qo'shish(830 qator ma'lumot qo'shildi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **order_details** jadvalini yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **order_details** jadvaliga ma'lumot qo'shish(2155 qator ma'lumot qo'shildi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **testproducts** jadvalini yaratish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **testproducts** jadvaliga ma'lumo qo'shish(10 qator ma'lumot qo'shildi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **where** operatorlari bilan ishlatiladi
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **where** orqali katta belgisi(>)ni ishlatilishi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **where** ni kichik belgisi(<) bilan ishlatilishi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **where** ni teng belgisi(=) bilan ishlatilishi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <=, >=, <> yoki != ham shu tartibda ishlatiladi

# %% [markdown]
# **like** operatori qirish uchun ishlatiladi(**%** belgisi bir nechta belgi bo'lish mumkinligini bildiradi, **_** belgisi faqat 1 ta belgi bo'lish mumkinligini bildiradi)
#
# katta va kichik belgilarni farqlaydi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ilike** operatori qirish uchun ishlatiladi(**%** belgisi bir nechta belgi bo'lish mumkinligini bildiradi, **_** belgisi faqat 1 ta belgi bo'lish mumkinligini bildiradi)
#
# katta va kichik belgilarni farqlamaydi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **distinct** qiymatlarni unikal qilib qaytaradi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **where** orqali shart berib ma'lumot ko'rish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **order by** orqali ustun bo'yicha tartiblash
#
# **limit** bu birinchi kelgan belgilangancha qator chiqaradi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **order by** da **desc** teskari tartiblash uchun qo'llaniladi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **limit** da **offset** orqali qaysi qatordan boshlab ma'lumotni ekranga chiqarishni belgilaydi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **min()** orqali minimal qiymat topiladi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **max()** orqali maxsimal qiymat topiladi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **AS** orqali ustunga nom berish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **count()** orqali qatorlar sonini sanash

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **sum()** orqali yig'indini hisoblash

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **avg()** orqali o'rtachani hisoblash
#
# ::numeric() bu nechta son olishni bildirad(ishlatish ixtiyoriy(

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **in** orqali ro'yhatda bor qatorlarni chiqarish
#
# **not in** esa teskarisi, ro'yhatda yo'qlarini chiqaradi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **between** orqali orasidagi ma'lumotlarni chiqarish

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **products** jadvalidagi **category_id** va **category_id** jadvalidagi **id** ustuniga mos qiymatlarni 1 qatorda chiqaradi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# join turlari

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **group by** orqali ustunlar ni guruhlasg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# having group bu bilan ishlatiladi(shart berish uchun, yandex ishlamaydi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
